# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress



# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset and display the data table for preview

merge_df = pd.merge(mouse_metadata, study_results, on='Mouse ID', how='outer')
merge_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
#Checking the number of mice
mice_count = merge_df.groupby("Mouse ID")
mice_count

#Number of mice = 249
mice_total = len(mice_count["Mouse ID"].count())
mice_total
# Out:
# 249

# %%
# Use pandas duplicated function to identify he duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse_ids = merge_df[merge_df.duplicated(subset=['Mouse ID','Timepoint'], keep=False)]
duplicate_mouse_ids


gender_df = merge_df.drop_duplicates(subset= ['Mouse ID'])
gender_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data_df = merge_df[merge_df["Mouse ID"] != "g989"]
clean_data_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mice_count2 = clean_data_df.groupby("Mouse ID")

#Number of mice = 248
mice_total2= len(mice_count2["Mouse ID"].count())
mice_total2
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

summary_table2 = clean_data_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean","median","var","std","sem"]})
summary_table2
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen


tumorstats_df = clean_data_df.groupby(["Drug Regimen"])
mean_statistic = tumorstats_df["Tumor Volume (mm3)"].var()
median_statistic = tumorstats_df["Tumor Volume (mm3)"].median()
variance_statistic = tumorstats_df["Tumor Volume (mm3)"].var()
sd_statistics = tumorstats_df["Tumor Volume (mm3)"].std()
sem_statistics = tumorstats_df["Tumor Volume (mm3)"].sem()


tumorvol_summary_df = pd.DataFrame({"Tumor Volume Mean":mean_statistic,
                                    "Tumor Volume Median":median_statistic,
                                    "Tumor Volume Variance":variance_statistic,
                                    "Tumor Volume Standard Deviation":sd_statistics,
                                    "Tumor Volume SEM":sem_statistics})

tumorvol_summary_df.head()
# Out:
#               Tumor Volume Mean  Tumor Volume Median  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             24.947764            41.557809              24.947764
# Ceftamin              39.290177            51.776157              39.290177
# Infubinol             43.128684            51.820584              43.128684
# Ketapril              68.553577            53.698743              68.553577
# Naftisol              66.173479            52.509285              66.173479
#
#               Tumor Volume Standard Deviation  Tumor Volume SEM
# Drug Regimen
# Capomulin                            4.994774          0.329346
# Ceftamin                             6.268188          0.469821
# Infubinol                            6.567243          0.492236
# Ketapril                             8.279709          0.603860
# Naftisol                             8.134708          0.596466

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 

barplot = merge_df.groupby('Drug Regimen').count()['Tumor Volume (mm3)']
forpanbar = pd.DataFrame(barplot)


also = forpanbar.plot.bar(legend=False,rot=50)
also
plt.ylabel("Number of Mice for each Treatment")
plt.title("Number of Mice for each Drug Treatment")

plt.savefig("BarPlot1")

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

x_axis = np.arange(len(barplot))

tick_locations = [x for x in x_axis]
#for x in x_axis:
#tick_locations.append(x)

plt.figure(figsize=(5,3))
#plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
#plt.xticks(tick_locations, rain_df["State"], rotation="vertical")

newtry = forpanbar.reset_index()
newtry

plt.bar(x_axis, forpanbar['Tumor Volume (mm3)'], alpha=0.75, align="center")
plt.xticks(tick_locations, newtry['Drug Regimen'],rotation="vertical")

plt.xlim(-0.75, len(barplot)-.25)
plt.ylim(0, 250)

plt.title("Number of Mice for each Drug Treatment")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice for each Treatment")


plt.savefig("BarPlot2")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas 

gender = clean_data_df.groupby("Sex").nunique()
gender
# Out:
#         Mouse ID  Drug Regimen  Sex  Age_months  Weight (g)  Timepoint  \
# Sex
# Female       123            10    1          24          14         10
# Male         125            10    1          24          14         10
#
#         Tumor Volume (mm3)  Metastatic Sites
# Sex
# Female                 800                 5
# Male                   834                 5

# %%
#labels 
labels = [clean_data_df["Sex"].unique()]
genderlist = list(gender.index)
genderlist
# Out:
# ['Female', 'Male']

# %%
#gendercount for pie
sizes = [gender["Mouse ID"]]
sizes
# Out:
# [Sex
#  Female    123
#  Male      125
#  Name: Mouse ID, dtype: int64]

# %%
#pie chart 
colors = ["blue", "orange"]

plt.pie(sizes, labels=genderlist, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=180)
plt.title('Male vs Female Mice')
plt.ylabel('Sex')

plt.savefig("PieChart1")
# Out:
# <ipython-input-13-e3b9d909e872>:4: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.pie(sizes, labels=genderlist, colors=colors,

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot


# pieplot = gender_df2["Mouse ID"].plot.pie(y='sizes', figsize=(5, 5), autopct="%1.1f%%",startangle=180)
# plt.title('Male vs Female Mouse Population')
# plt.ylabel('Sex')



# Generate a pie plot showing the distribution of female versus male mice using pyplot

piechart2 = gender["Mouse ID"].plot.pie(y='sizes', figsize=(5, 5), autopct="%1.1f%%",startangle=180)
plt.title('Male vs Female Mice')
plt.ylabel('Sex')

plt.savefig("PieChart2")

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

mouse_df = clean_data_df.groupby(["Mouse ID"])["Timepoint"].max()
mouse_df = mouse_df.reset_index()
mouse_df.head()
newmerge_df = mouse_df.merge(clean_data_df, on= ["Mouse ID", "Timepoint"], how = "left")
newmerge_df.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     a203         45    Infubinol  Female          20          23
# 1     a251         45    Infubinol  Female          21          25
# 2     a262         45      Placebo  Female          17          29
# 3     a275         45     Ceftamin  Female          20          28
# 4     a366         30     Stelasyn  Female          16          29
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           67.973419                 2
# 1           65.525743                 1
# 2           70.717621                 4
# 3           62.999356                 3
# 4           63.440686                 1

# %%
# Put treatments into a list for for loop (and later for plot labels)

treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
tumor_vol = []
for drug in treatment_list:
    final_tumor = newmerge_df.loc[newmerge_df['Drug Regimen'] == drug, 'Tumor Volume (mm3)']
    tumor_vol.append(final_tumor)
quartiles = final_tumor.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"The value following is the IQR: {iqr}")
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The value following is the IQR: 15.577752179999997
# Values below 25.355449580000002 could be outliers.
# Values above 87.66645829999999 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume for Drug Regimen')
ax1.set_ylabel('Tumor Volume')
ax1.boxplot(tumor_vol)
plt.show()

plt.savefig("BoxPlot1")

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

capomulin_table = clean_data_df.loc[clean_data_df["Drug Regimen"]=="Capomulin"]
capomulin_mouse = clean_data_df.loc[clean_data_df["Mouse ID"]=="l509"]

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

timepoint = capomulin_table["Timepoint"]
tumorsize = capomulin_table["Tumor Volume (mm3)"]

plt.title('Capomulin treatmeant for mouse l509')
plt.plot(timepoint, tumorsize,linewidth=2, markersize=12)
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')

plt.savefig("LinePlot1")

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

capomulin_table = clean_data_df.loc[clean_data_df["Drug Regimen"]=="Capomulin"]
capomulin_average = capomulin_table.groupby("Mouse ID").mean()
plt.scatter(capomulin_average['Weight (g)'],capomulin_average["Tumor Volume (mm3)"])


plt.savefig("ScatterPlot")

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen



x_values = capomulin_table["Weight (g)"]
y_values = capomulin_table["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Mouse Weight")
plt.ylabel("Average Volume")
plt.savefig("Correlation and Regression")
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.2763600223455911
